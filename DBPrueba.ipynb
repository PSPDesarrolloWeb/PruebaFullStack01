-- %% [markdown]
-- # [prueba]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [prueba]    Script Date: 31/1/2024 18:50:36 ******/
CREATE DATABASE [prueba]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'prueba', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\prueba.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'prueba_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\prueba_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [prueba] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [prueba].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [prueba] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [prueba] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [prueba] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [prueba] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [prueba] SET ARITHABORT OFF 
GO
ALTER DATABASE [prueba] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [prueba] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [prueba] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [prueba] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [prueba] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [prueba] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [prueba] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [prueba] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [prueba] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [prueba] SET  ENABLE_BROKER 
GO
ALTER DATABASE [prueba] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [prueba] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [prueba] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [prueba] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [prueba] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [prueba] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [prueba] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [prueba] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [prueba] SET  MULTI_USER 
GO
ALTER DATABASE [prueba] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [prueba] SET DB_CHAINING OFF 
GO
ALTER DATABASE [prueba] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [prueba] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [prueba] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [prueba] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [prueba] SET QUERY_STORE = ON
GO
ALTER DATABASE [prueba] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[cargos]

-- %%
USE [prueba]
GO

-- %%
/****** Object:  Table [dbo].[cargos]    Script Date: 31/1/2024 18:50:36 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[cargos](
	[id_cg] [int] NOT NULL,
	[codigo_cg] [varchar](255) NOT NULL,
	[nombre_cg] [varchar](255) NOT NULL,
	[activo] [bit] NOT NULL,
	[idUsuarioCreacion_cg] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id_cg] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[departamentos]

-- %%
/****** Object:  Table [dbo].[departamentos]    Script Date: 31/1/2024 18:50:36 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[departamentos](
	[id_dep] [int] NOT NULL,
	[codigo_dep] [varchar](255) NOT NULL,
	[nombre_dep] [varchar](255) NOT NULL,
	[activo_dep] [bit] NOT NULL,
	[idUsuarioCreacion_dep] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id_dep] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[users]

-- %%
/****** Object:  Table [dbo].[users]    Script Date: 31/1/2024 18:50:36 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[users](
	[usuario_us] [varchar](255) NOT NULL,
	[primerNombre_us] [varchar](255) NOT NULL,
	[segundoNombre_us] [varchar](255) NOT NULL,
	[primerApellido_us] [varchar](255) NOT NULL,
	[segundoApellido_us] [varchar](255) NOT NULL,
	[idDepartamento_us] [int] NOT NULL,
	[idCargo_us] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[usuario_us] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[cargos]

-- %%
INSERT [dbo].[cargos] ([id_cg], [codigo_cg], [nombre_cg], [activo], [idUsuarioCreacion_cg]) VALUES (1, N'2V5RA8', N'Financiero', 1, 1)
INSERT [dbo].[cargos] ([id_cg], [codigo_cg], [nombre_cg], [activo], [idUsuarioCreacion_cg]) VALUES (2, N'58s5w1', N'Técnico', 1, 1)
GO

-- %% [markdown]
-- # [dbo].[departamentos]

-- %%
INSERT [dbo].[departamentos] ([id_dep], [codigo_dep], [nombre_dep], [activo_dep], [idUsuarioCreacion_dep]) VALUES (1, N'A1B2C3', N'Tecnologías de la información', 1, 1)
INSERT [dbo].[departamentos] ([id_dep], [codigo_dep], [nombre_dep], [activo_dep], [idUsuarioCreacion_dep]) VALUES (2, N'E2D5Q9', N'Legal', 1, 1)
GO

-- %% [markdown]
-- # [dbo].[users]

-- %%
INSERT [dbo].[users] ([usuario_us], [primerNombre_us], [segundoNombre_us], [primerApellido_us], [segundoApellido_us], [idDepartamento_us], [idCargo_us]) VALUES (N'PPicapiedra', N'Pedro', N'Pablo', N'Picapiedra', N'Marmol', 1, 1)
INSERT [dbo].[users] ([usuario_us], [primerNombre_us], [segundoNombre_us], [primerApellido_us], [segundoApellido_us], [idDepartamento_us], [idCargo_us]) VALUES (N'pumamusic', N'Bryan', N'Santiago', N'Puma', N'Criollo', 1, 1)
GO

-- %% [markdown]
-- # [FK__users__idCargo_u__4E88ABD4]

-- %%
ALTER TABLE [dbo].[users]  WITH CHECK ADD FOREIGN KEY([idCargo_us])
REFERENCES [dbo].[cargos] ([id_cg])
GO

-- %% [markdown]
-- # [FK__users__idDeparta__4D94879B]

-- %%
ALTER TABLE [dbo].[users]  WITH CHECK ADD FOREIGN KEY([idDepartamento_us])
REFERENCES [dbo].[departamentos] ([id_dep])
GO

-- %% [markdown]
-- # [prueba]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [prueba] SET  READ_WRITE 
GO
